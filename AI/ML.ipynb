# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-Maidul/Python-for-ML/blob/main/AI/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# 1. New Input: Let's assume these 4 features represent
image_features = torch.tensor([[0.15, 0.85, 0.25, 0.70]])

# 2. Updated Network Architecture
model = nn.Sequential(
    nn.Linear(4, 12),
    nn.ReLU(),
    nn.Linear(12, 1),
    nn.Sigmoid()
)

# 3. Get prediction
# Note: We use torch.no_grad() because we aren't training right now
with torch.no_grad():
    prediction = model(image_features)


prob = prediction.item()
print(f"Probability of being a Dog: {prob:.4f}")

# 4. Interpret the result

if prob==0.5:
  print("Couldn't classify the image")
elif prob>0.5:
  print("Cat")
else:
  print("Dog")
# Out:
# Probability of being a Dog: 0.4789
# Dog
