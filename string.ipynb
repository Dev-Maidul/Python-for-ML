# %%
string="Hello world"
print(string)

# %% [markdown]
# ### Multiline String

# %%
message="""
Hi, there . I am Md Maidul Islam.
I started to learn AI/ML.
As I am a CSE student and now I am in 3rd year student.
I have plan to do my masters degree on Maching Learning that's why I started to learn maching learning

"""
print(message)
# Out:
# Hi, there . I am Md Maidul Islam.
# I started to learn AI/ML.
# As I am a CSE student and now I am in 3rd year student.
# I have plan to do my masters degree on Maching Learning that's why I started to learn maching learning

# %% [markdown]
# ### String slicing and Indexing

# %%
firstLine=message[0:35]
print(firstLine)
# Out:
# Hi, there . I am Md Maidul Islam.

# %%
print(len(message))
processed_message=message.lower()
print(processed_message)
# Out:
# 221
#
# hi, there . i am md maidul islam.
# i started to learn ai/ml.
# as i am a cse student and now i am in 3rd year student.
# i have plan to do my masters degree on maching learning that's why i started to learn maching learning

# %% [markdown]
# ### Spliting,joining and formating

# %%
prompt="What are you doing ?"
token=prompt.split();
print(token)
joinPrompt="-".join(token)
print(joinPrompt)
name="Maidul"
age=26
height=5.74343
print(f"My name is {name}. I am {age} years old and height is {height:.2}")
model_accuracy=0.83333
print(f"The model accuracy is around {model_accuracy:.2%}")
# Out:
# ['What', 'are', 'you', 'doing', '?']
# What-are-you-doing-?
# My name is Maidul. I am 26 years old and height is 5.7
# The model accuracy is around 83.33%
