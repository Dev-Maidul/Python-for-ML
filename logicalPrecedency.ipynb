# %% [markdown]
# Logical operator

# %%
x=10; y=5; z=3;
result=x>y and x>z
print(result)
# Out:
# True

# %%
x=10; y=5; z=13;
result=x>y and x>z
print(result)
# Out:
# False

# %%
x=10; y=5; z=13;
result=x<y or x<z
print(result)
# Out:
# True

# %%
x=10; y=5; z=3;
result=x<y or x<z
print(result)
# Out:
# False

# %% [markdown]
# Precedency and Associativity

# %%
ans=(10+10)/2-5*2;
ans
# Out:
# 0.0
