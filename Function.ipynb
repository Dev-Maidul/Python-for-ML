# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-Maidul/Python-for-ML/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def welcome_Message():
    print("Hello user")

welcome_Message()
# Out:
# Hello user

# %%
def welcome_Message(user=""):
    print(f"Hello {user}")

welcome_Message("Machine Learning")
# Out:
# Hello Machine Learning

# %%
def adder(a,b):
  """
  Add two int number
  """
  return a+b

# %%
ans=adder(10,20)*5
print(ans)
# Out:
# 150

# %%
def adder(*args):
  for i in args:
    print(i)


adder(23,22,12)
# Out:
# 23
# 22
# 12

# %% [markdown]
# Keyword ***Arguments***

# %%
def adderkeyword(**kwargs):
  for key,value in kwargs.items():
    print(f"{key}: {value}")


adderkeyword(a=10,b=40,estimator=33)
# Out:
# a: 10
# b: 40
# estimator: 33

# %% [markdown]
# Keyword ***Arguments***

# %% [markdown]
# Keyword ***Arguments***
