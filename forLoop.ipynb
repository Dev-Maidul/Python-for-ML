# %% [markdown]
# ### For Loop

# %%
for i in range(1,11):
    for j in range(1,11,2):
        print(i,j,"Hello World")
# Out:
# 1 1 Hello World
# 1 3 Hello World
# 1 5 Hello World
# 1 7 Hello World
# 1 9 Hello World
# 2 1 Hello World
# 2 3 Hello World
# 2 5 Hello World
# 2 7 Hello World
# 2 9 Hello World
# 3 1 Hello World
# 3 3 Hello World
# 3 5 Hello World
# 3 7 Hello World
# 3 9 Hello World
# 4 1 Hello World
# 4 3 Hello World
# 4 5 Hello World
# 4 7 Hello World
# 4 9 Hello World
# 5 1 Hello World
# 5 3 Hello World
# 5 5 Hello World
# 5 7 Hello World
# 5 9 Hello World
# 6 1 Hello World
# 6 3 Hello World
# 6 5 Hello World
# 6 7 Hello World
# 6 9 Hello World
# 7 1 Hello World
# 7 3 Hello World
# 7 5 Hello World
# 7 7 Hello World
# 7 9 Hello World
# 8 1 Hello World
# 8 3 Hello World
# 8 5 Hello World
# 8 7 Hello World
# 8 9 Hello World
# 9 1 Hello World
# 9 3 Hello World
# 9 5 Hello World
# 9 7 Hello World
# 9 9 Hello World
# 10 1 Hello World
# 10 3 Hello World
# 10 5 Hello World
# 10 7 Hello World
# 10 9 Hello World
