# %%
tup=(10,22,1,1,4,5,63,"maidul",False,33.333,3,3,3,3,3,3,2,2,2,2,1,1,1,1,1,1)
# print(tup.count(1))
#indexing of tuple
print(tup.index(False))
print(tup.index(33.333))
print(tup.index("maidul"))

new_tup=tup[0:4]
print(new_tup)
tup_3=tup[7:13]
print(tup_3)
# Out:
# 8
# 9
# 7
# (10, 22, 1, 1)
# ('maidul', False, 33.333, 3, 3, 3)
