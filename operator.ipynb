# %%
# Arithmetic operator
x=10;y=3;
sum=x+y;
sub=x-y;
mul=x*y;
div=round(x/y,1);
rem=x%y;
# print(sum,sub,mul,div,rem);

## Logical Operator
greater_than=x>y;
greater_than_equal=x>=y;
less_than=x<y;
less_than_equal=x<=y;
equal=x==y;
not_equal=x!=y;
print(greater_than,greater_than_equal,less_than,less_than_equal,equal,not_equal)
# Out:
# True True False False False True
