# %%
name=str(input("Please Enter your name: "))
print(name,type(name))
# Out:
# Md Maidul Islam <class 'str'>

# %%
age=int(input("Please Enter your age: "))
print(age,type(age))
# Out:
# 22 <class 'int'>

# %%
height=float(input("Enter your height: "))
print(height,type(height))
# Out:
# 5.6 <class 'float'>

# %%
isGraduate=bool(input("Did you complete your graduation"))
print(isGraduate,type(isGraduate))
# Out:
# True <class 'bool'>
