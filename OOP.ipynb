# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-Maidul/Python-for-ML/blob/main/OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Class and Object

# %%
class Student:
  def __init__(self,name):
    self.name=name
s=Student("Rafi")
print(s.name)
# Out:
# Rafi

# %%
class Phone:
  category="Electronics"

  #constructor
  def __init__(self,model,battery,camera,bh):
    self.model=model
    self.battery=battery
    self.camera=camera
    self.bh=bh
  # method
  def charge(self,hour):
    print(f"charge completed by {hour}")

# %%
apple=Phone("16 Pro","3000 Mh","48 MGP","89%")
print(apple.model)
samsung=Phone("24 Ultra","3000 Mh","48 MGP","100%")
print(samsung.model)
print(apple.charge(2))
# Out:
# 16 Pro
# 24 Ultra
# charge completed by 2
# None
