# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-Maidul/Python-for-ML/blob/main/FileHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1  Create and Write to a File
#
#
# Write a function create_file(filename, content) that creates a new text file with the given filename and writes the content into it. Call it using positional arguments.
#
# 📥 Sample Input:
# "notes.txt", "Hello, this is my first file."
# 📤 Sample Output (notes.txt will contain):
# Hello, this is my first file.

# %% [markdown]
# Problem 1  Create and Write to a File
#
#
# Write a function create_file(filename, content) that creates a new text file with the given filename and writes the content into it. Call it using positional arguments.
#
# 📥 Sample Input:
# "notes.txt", "Hello, this is my first file."
# 📤 Sample Output (notes.txt will contain):
# Hello, this is my first file.

# %% [markdown]
# File Read

# %%
with open("./sample_data/sample.txt","r") as file:
  for line in file:
    # print(line,end="")
    l=line.strip()
    print(l)
# Out:
# Hello Maidul.
# Welcome to AI/ML course.
# Hope you will do hard

# %% [markdown]
# Write File

# %%
# Create a new file if file not exist and write there
with open("./sample_data/test.txt","w") as file:
  file.write("Hello student\n")
  file.write("How is going class?\n")

# %% [markdown]
# Append File

# %%
with open("./sample_data/test.txt","a") as file:
  file.writelines("What you learn about file Handling?\n")
  file.writelines("Do you have any issues about course?\n")

# %%
text=["Hello\n","hi\n","whatsup\n"]
with open("./sample_data/test.txt","a") as file:
  for tst in text:
    file.writelines(tst)
    file.writelines("\n")

# %% [markdown]
# File Pointer

# %%
with open("./sample_data/test.txt","r") as file:
  # tell method mean where is my cursor/pointer
  print(file.tell())
  print(file.read(5))
  print(file.tell())
  # seek method means we can move cursor backward and forward
  print(file.seek(10))
  print(file.read(5))
  print(file.tell())
# Out:
# 0
# Hello
# 5
# 10
# ent
# H
# 15

# %% [markdown]
# Exception Handling

# %%
n=int(input())
try:
  a=10/0
except Exception as e:
  print(e)
else:
  print(10/n)
finally:
  print("Program stopped")
# Out:
# 4
# division by zero
# Program stopped

# %% [markdown]
# Problem 1  Create and Write to a File
#
#
# Write a function create_file(filename, content) that creates a new text file with the given filename and writes the content into it. Call it using positional arguments.
#
# 📥 Sample Input:
# "notes.txt", "Hello, this is my first file."
# 📤 Sample Output (notes.txt will contain):
# Hello, this is my first file.

# %%
filename=input()
content=input()
def create_file(filename, content):
  with open(f"./sample_data/{filename}","w") as file:
    file.write(content)

create_file(filename,content)
# Out:
# notes.txt
# Hello, this is my first file.
