# %%
raining=False
if raining:
    print("Please take umbrella")
else:
    print("Umbrella is not requried.It's sunny day")
# Out:
# Umbrella is not requried.It's sunny day

# %%
balance=1000;
raining=True

if(balance>500) and (raining==False):
    print("I will go out")

else:
    print("I will stay at home")
# Out:
# I will stay at home
